# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision.models import resnet18, ResNet18_Weights
from torch import nn
import numpy as np
import utils

torch.manual_seed(42069)
# if gpu available else cpu
device = torch.device(0) if torch.cuda.is_available() else torch.device('cpu')
TRAIN_MEAN = [0.5036, 0.4719, 0.3897]
TRAIN_STD = [0.2623, 0.2577, 0.2671]
classes = ['butterfly','cat', 'chicken', 'cow', 'dog', 'elephant', 'horse', 'sheep', 'spider', 'squirrel']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('models/results.csv')
df.head()
# Out:
#         session_id  epoch   loss  train_acc  test_acc
# 0  20221209_195344      1  0.547      0.829     0.899
# 1  20221209_195344      2  0.329      0.894     0.912
# 2  20221209_195344      3  0.294      0.905     0.915
# 3  20221209_195344      4  0.292      0.904     0.923
# 4  20221209_195344      5  0.271      0.913     0.923

# %%
df = df[df.session_id == '20221209_195344']
plt.plot(df['epoch'], df['loss'])
plt.plot(df['epoch'], df['train_acc'])
plt.plot(df['epoch'], df['test_acc'])
plt.legend(['loss,', 'train_acc', 'test_acc'])
plt.title('Training metrics per epoch'), plt.xlabel('Epoch')
plt.show()
