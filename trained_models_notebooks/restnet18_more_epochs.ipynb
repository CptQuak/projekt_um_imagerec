# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision.models import resnet18, ResNet18_Weights
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import utils

torch.manual_seed(421)
# if gpu available else cpu
device = torch.device(0) if torch.cuda.is_available() else torch.device('cpu')
TRAIN_MEAN = [0.5036, 0.4719, 0.3897]
TRAIN_STD = [0.2623, 0.2577, 0.2671]
classes = ['butterfly','cat', 'chicken', 'cow', 'dog', 'elephant', 'horse', 'sheep', 'spider', 'squirrel']

# %% [markdown]
# ## Przygotowanie danych

# %%
# zdefiniowanie operacji na kazdym obrazie w zbiorze
transform = transforms.Compose([
    transforms.RandomResizedCrop(256),  #  na 256x256
    transforms.RandomHorizontalFlip(),  # wycinamy losowy fragment 128x128
    transforms.ToTensor(),              # obrazy zamieniamy na tensory,
    # srednie i odchylenia po kanałach całęgo zbioru,
    #  wyliczone wczesniej za pomocą utils.data_normalize_values
    transforms.Normalize(TRAIN_MEAN, TRAIN_STD)
])

# loader danych z batchami
train_data = ImageFolder(root='dataset/train/', transform=transform)
test_data = ImageFolder(root='dataset/test/', transform=transform)
batch_size = 16
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# ## Uczenie klasyfikatora

# %%
# RESNET18 z wagami przetrenowanymi na zbiorze IMAGENET
res_net_model = resnet18(weights=None)
# res_net_model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
# dostosowanie ostatniego layeru do problemu
res_net_model.fc = nn.Linear(res_net_model.fc.in_features, len(classes))
# inicjalizacja wag w warstwie wyjsciowej
nn.init.xavier_uniform_(res_net_model.fc.weight)


res_net_model = res_net_model.to(device)
metrics = utils.train_fine_tuning_long_train(
    model = res_net_model, 
    learning_rate= 1e-2, 
    train_loader=train_loader,
    test_loader=test_loader,
    device=device, num_epochs=100, param_group=False
)
# Out:
# Progress: 1/100 epochs
# Epoch: 1, Loss 2.12, Train acc: 0.282, Test acc: 0.329
# Progress: 2/100 epochs
# Epoch: 2, Loss 1.72, Train acc: 0.407, Test acc: 0.401
# Progress: 3/100 epochs
# Epoch: 3, Loss 1.535, Train acc: 0.468, Test acc: 0.436
# Progress: 4/100 epochs
# Epoch: 4, Loss 1.401, Train acc: 0.52, Test acc: 0.505
# Progress: 5/100 epochs
# Epoch: 5, Loss 1.311, Train acc: 0.552, Test acc: 0.53
# Progress: 6/100 epochs
# Epoch: 6, Loss 1.228, Train acc: 0.582, Test acc: 0.528
# Progress: 7/100 epochs
# Epoch: 7, Loss 1.13, Train acc: 0.614, Test acc: 0.632
# Progress: 8/100 epochs
# Epoch: 8, Loss 1.071, Train acc: 0.635, Test acc: 0.636
# Progress: 9/100 epochs
# Epoch: 9, Loss 1.011, Train acc: 0.655, Test acc: 0.646
# Progress: 10/100 epochs
# Epoch: 10, Loss 0.957, Train acc: 0.675, Test acc: 0.66
# Progress: 11/100 epochs
# Epoch: 11, Loss 0.899, Train acc: 0.697, Test acc: 0.653
# Progress: 12/100 epochs
# Epoch: 12, Loss 0.855, Train acc: 0.711, Test acc: 0.678
# Progress: 13/100 epochs
# Epoch: 13, Loss 0.808, Train acc: 0.727, Test acc: 0.724
# Progress: 14/100 epochs
# Epoch: 14, Loss 0.78, Train acc: 0.742, Test acc: 0.704
# Progress: 15/100 epochs
# Epoch: 15, Loss 0.747, Train acc: 0.752, Test acc: 0.75
# Progress: 16/100 epochs
# Epoch: 16, Loss 0.71, Train acc: 0.765, Test acc: 0.734
# Progress: 17/100 epochs
# Epoch: 17, Loss 0.679, Train acc: 0.772, Test acc: 0.76
# Progress: 18/100 epochs
# Epoch: 18, Loss 0.655, Train acc: 0.782, Test acc: 0.782
# Progress: 19/100 epochs
# Epoch: 19, Loss 0.64, Train acc: 0.786, Test acc: 0.772
# Progress: 20/100 epochs
# Epoch: 20, Loss 0.616, Train acc: 0.795, Test acc: 0.771
# Progress: 21/100 epochs
# Epoch: 21, Loss 0.594, Train acc: 0.801, Test acc: 0.792
# Progress: 22/100 epochs
# Epoch: 22, Loss 0.567, Train acc: 0.814, Test acc: 0.762
# Progress: 23/100 epochs
# Epoch: 23, Loss 0.567, Train acc: 0.811, Test acc: 0.771
# Progress: 24/100 epochs
# Epoch: 24, Loss 0.536, Train acc: 0.82, Test acc: 0.801
# Progress: 25/100 epochs
# Epoch: 25, Loss 0.536, Train acc: 0.821, Test acc: 0.803
# Progress: 26/100 epochs
# Epoch: 26, Loss 0.519, Train acc: 0.826, Test acc: 0.806
# Progress: 27/100 epochs
# Epoch: 27, Loss 0.501, Train acc: 0.833, Test acc: 0.806
# Progress: 28/100 epochs
# Epoch: 28, Loss 0.484, Train acc: 0.839, Test acc: 0.802
# Progress: 29/100 epochs
# Epoch: 29, Loss 0.471, Train acc: 0.842, Test acc: 0.818
# Progress: 30/100 epochs
# Epoch: 30, Loss 0.465, Train acc: 0.846, Test acc: 0.82
# Progress: 31/100 epochs
# Epoch: 31, Loss 0.445, Train acc: 0.852, Test acc: 0.828
# Progress: 32/100 epochs
# Epoch: 32, Loss 0.44, Train acc: 0.852, Test acc: 0.837
# Progress: 33/100 epochs
# Epoch: 33, Loss 0.43, Train acc: 0.857, Test acc: 0.828
# Progress: 34/100 epochs
# Epoch: 34, Loss 0.426, Train acc: 0.859, Test acc: 0.833
# Progress: 35/100 epochs
# Epoch: 35, Loss 0.404, Train acc: 0.865, Test acc: 0.831
# Progress: 36/100 epochs
# Epoch: 36, Loss 0.405, Train acc: 0.864, Test acc: 0.842
# Progress: 37/100 epochs
# Epoch: 37, Loss 0.387, Train acc: 0.872, Test acc: 0.846
# Progress: 38/100 epochs
# Epoch: 38, Loss 0.391, Train acc: 0.871, Test acc: 0.843
# Progress: 39/100 epochs
# Epoch: 39, Loss 0.381, Train acc: 0.876, Test acc: 0.837
# Progress: 40/100 epochs
# Epoch: 40, Loss 0.37, Train acc: 0.875, Test acc: 0.841
# Progress: 41/100 epochs
# Epoch: 41, Loss 0.362, Train acc: 0.879, Test acc: 0.848
# Progress: 42/100 epochs
# Epoch: 42, Loss 0.353, Train acc: 0.885, Test acc: 0.847
# Progress: 43/100 epochs
# Epoch: 43, Loss 0.352, Train acc: 0.885, Test acc: 0.842
# Progress: 44/100 epochs
# Epoch: 44, Loss 0.342, Train acc: 0.886, Test acc: 0.844
# Progress: 45/100 epochs
# Epoch: 45, Loss 0.337, Train acc: 0.886, Test acc: 0.858
# Progress: 46/100 epochs
# Epoch: 46, Loss 0.336, Train acc: 0.89, Test acc: 0.856
# Progress: 47/100 epochs
# Epoch: 47, Loss 0.316, Train acc: 0.895, Test acc: 0.856
# Progress: 48/100 epochs
# Epoch: 48, Loss 0.328, Train acc: 0.894, Test acc: 0.858
# Progress: 49/100 epochs
# Epoch: 49, Loss 0.317, Train acc: 0.896, Test acc: 0.857
# Progress: 50/100 epochs
# Epoch: 50, Loss 0.309, Train acc: 0.896, Test acc: 0.857
# Progress: 51/100 epochs
# Epoch: 51, Loss 0.304, Train acc: 0.898, Test acc: 0.855
# Progress: 52/100 epochs
# Epoch: 52, Loss 0.295, Train acc: 0.904, Test acc: 0.857
# Progress: 53/100 epochs
# Epoch: 53, Loss 0.289, Train acc: 0.906, Test acc: 0.862
# Progress: 54/100 epochs
# Epoch: 54, Loss 0.294, Train acc: 0.902, Test acc: 0.863
# Progress: 55/100 epochs
# Epoch: 55, Loss 0.293, Train acc: 0.903, Test acc: 0.863
# Progress: 56/100 epochs
# Epoch: 56, Loss 0.287, Train acc: 0.906, Test acc: 0.861
# Progress: 57/100 epochs
# Epoch: 57, Loss 0.283, Train acc: 0.908, Test acc: 0.861
# Progress: 58/100 epochs
# Epoch: 58, Loss 0.269, Train acc: 0.909, Test acc: 0.867
# Progress: 59/100 epochs
# Epoch: 59, Loss 0.272, Train acc: 0.911, Test acc: 0.866
# Progress: 60/100 epochs
# Epoch: 60, Loss 0.268, Train acc: 0.913, Test acc: 0.869
# Progress: 61/100 epochs
# Epoch: 61, Loss 0.269, Train acc: 0.911, Test acc: 0.869
# Progress: 62/100 epochs
# Epoch: 62, Loss 0.26, Train acc: 0.914, Test acc: 0.873
# Progress: 63/100 epochs
# Epoch: 63, Loss 0.265, Train acc: 0.914, Test acc: 0.878
# Progress: 64/100 epochs
# Epoch: 64, Loss 0.243, Train acc: 0.918, Test acc: 0.872
# Progress: 65/100 epochs
# Epoch: 65, Loss 0.267, Train acc: 0.912, Test acc: 0.866
# Progress: 66/100 epochs
# Epoch: 66, Loss 0.248, Train acc: 0.918, Test acc: 0.87
# Progress: 67/100 epochs
# Epoch: 67, Loss 0.252, Train acc: 0.918, Test acc: 0.86
# Progress: 68/100 epochs
# Epoch: 68, Loss 0.244, Train acc: 0.919, Test acc: 0.869
# Progress: 69/100 epochs
# Epoch: 69, Loss 0.245, Train acc: 0.919, Test acc: 0.869
# Progress: 70/100 epochs
# Epoch: 70, Loss 0.232, Train acc: 0.923, Test acc: 0.87
# Progress: 71/100 epochs
# Epoch: 71, Loss 0.237, Train acc: 0.922, Test acc: 0.867
# Progress: 72/100 epochs
# Epoch: 72, Loss 0.237, Train acc: 0.921, Test acc: 0.869
# Progress: 73/100 epochs
# Epoch: 73, Loss 0.243, Train acc: 0.919, Test acc: 0.868
# Progress: 74/100 epochs
# Epoch: 74, Loss 0.242, Train acc: 0.919, Test acc: 0.873
# Progress: 75/100 epochs
# Epoch: 75, Loss 0.238, Train acc: 0.923, Test acc: 0.877
# Progress: 76/100 epochs
# Epoch: 76, Loss 0.232, Train acc: 0.924, Test acc: 0.87
# Progress: 77/100 epochs
# Epoch: 77, Loss 0.222, Train acc: 0.928, Test acc: 0.867
# Progress: 78/100 epochs
# Epoch: 78, Loss 0.231, Train acc: 0.924, Test acc: 0.871
# Progress: 79/100 epochs
# Epoch: 79, Loss 0.226, Train acc: 0.925, Test acc: 0.876
# Progress: 80/100 epochs
# Epoch: 80, Loss 0.217, Train acc: 0.932, Test acc: 0.873
# Progress: 81/100 epochs
# Epoch: 81, Loss 0.231, Train acc: 0.924, Test acc: 0.879
# Progress: 82/100 epochs
# Epoch: 82, Loss 0.216, Train acc: 0.928, Test acc: 0.873
# Progress: 83/100 epochs
# Epoch: 83, Loss 0.226, Train acc: 0.926, Test acc: 0.869
# Progress: 84/100 epochs
# Epoch: 84, Loss 0.222, Train acc: 0.927, Test acc: 0.866
# Progress: 85/100 epochs
# Epoch: 85, Loss 0.223, Train acc: 0.927, Test acc: 0.874
# Progress: 86/100 epochs
# Epoch: 86, Loss 0.225, Train acc: 0.926, Test acc: 0.872
# Progress: 87/100 epochs
# Epoch: 87, Loss 0.218, Train acc: 0.928, Test acc: 0.875
# Progress: 88/100 epochs
# Epoch: 88, Loss 0.216, Train acc: 0.928, Test acc: 0.877
# Progress: 89/100 epochs
# Epoch: 89, Loss 0.219, Train acc: 0.928, Test acc: 0.882
# Progress: 90/100 epochs
# Epoch: 90, Loss 0.222, Train acc: 0.928, Test acc: 0.874
# Progress: 91/100 epochs
# Epoch: 91, Loss 0.215, Train acc: 0.929, Test acc: 0.874
# Progress: 92/100 epochs
# Epoch: 92, Loss 0.213, Train acc: 0.93, Test acc: 0.87
# Progress: 93/100 epochs
# Epoch: 93, Loss 0.216, Train acc: 0.928, Test acc: 0.874
# Progress: 94/100 epochs
# Epoch: 94, Loss 0.214, Train acc: 0.93, Test acc: 0.875
# Progress: 95/100 epochs
# Epoch: 95, Loss 0.22, Train acc: 0.929, Test acc: 0.88
# Progress: 96/100 epochs
# Epoch: 96, Loss 0.211, Train acc: 0.931, Test acc: 0.878
# Progress: 97/100 epochs
# Epoch: 97, Loss 0.217, Train acc: 0.929, Test acc: 0.878
# Progress: 98/100 epochs
# Epoch: 98, Loss 0.211, Train acc: 0.931, Test acc: 0.879
# Progress: 99/100 epochs
# Epoch: 99, Loss 0.209, Train acc: 0.93, Test acc: 0.879
# Progress: 100/100 epochs
# Epoch: 100, Loss 0.213, Train acc: 0.929, Test acc: 0.876
